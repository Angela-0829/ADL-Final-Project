# %%
import matplotlib.pyplot as plt

constraint_x = [1, 3, 5, 10, 15, 18, 20]
constraint_r1 = [0.184, 0.215, 0.226, 0.230, 0.234, 0.236, 0.235]
constraint_r2 = [0.027, 0.026, 0.024, 0.023, 0.023, 0.023, 0.021]
constraint_b1 = [0.142, 0.168, 0.181, 0.183, 0.187, 0.189, 0.186]
constraint_b2 = [0.049, 0.052, 0.052, 0.050, 0.050, 0.050, 0.049]

size_x = [1, 3, 5, 10, 30, 50, 100, 150, 500]
size_r1 = [0.132, 0.164, 0.184, 0.215, 0.246, 0.255, 0.256, 0.259, 0.247]
size_r2 = [0.015, 0.022, 0.027, 0.038, 0.051, 0.053, 0.054, 0.053, 0.053]
size_b1 = [0.109, 0.130, 0.142, 0.156, 0.185, 0.192, 0.204, 0.187, 0.182]
size_b2 = [0.032, 0.044, 0.049, 0.062, 0.088, 0.091, 0.092, 0.091, 0.091]

plt.plot(constraint_x, constraint_r1)
plt.xlabel("number of augmentating words")
plt.title("rouge1 (swap, augmentation size=5)")
plt.show()
plt.plot(constraint_x, constraint_r2)
plt.xlabel("number of augmentating words")
plt.title("rouge2 (swap, augmentation size=5)")
plt.show()

plt.plot(constraint_x, constraint_b1)
plt.xlabel("number of augmentating words")
plt.title("bleu1 (swap, augmentation size=5)")
plt.show()

plt.plot(constraint_x, constraint_b2)
plt.xlabel("number of augmentating words")
plt.title("bleu2 (swap, augmentation size=5)")
plt.show()

plt.plot(size_x, size_r1)
plt.xlabel("augmentation size")
plt.title("rouge1 (swap, number of augmentating words=1)")
plt.show()

plt.plot(size_x, size_r2)
plt.xlabel("augmentation size")
plt.title("rouge2 (swap, number of augmentating words=1)")
plt.show()

plt.plot(size_x, size_b1)
plt.xlabel("augmentation size")
plt.title("bleu1 (swap, number of augmentating words=1)")
plt.show()

plt.plot(size_x, size_b2)
plt.xlabel("augmentation size")
plt.title("bleu2 (swap, number of augmentating words=1)")
plt.show()
